# %%
# import the necessary packages
from imutils import paths
import face_recognition
import argparse
import pickle
import cv2
import os

# %%
# construct the argument parser and parse the arguments
ap = argparse.ArgumentParser()
ap.add_argument("--dataset", required=True,help="path to input directory of faces + images")
ap.add_argument("--encodings", required=True,help="path to serialized db of facial encodings")
ap.add_argument("-d", "--detection-method", type=str, default="cnn",help="face detection model to use: either 'hog' or 'cnn'")

args = vars(ap.parse_args(["--dataset", "/Users/thejakamahaulpatha/PycharmProjects/Image Recognition/Project - Jurassic Park/dataset","--encodings","/Users/thejakamahaulpatha/PycharmProjects/Image Recognition/Project - Jurassic Park/encodings.pickle"]))

# %%
print("[INFO] quantifying faces...")
imagePaths = list(paths.list_images(args["dataset"]))
# imagePaths = list(paths.list_images("/Users/thejakamahaulpatha/PycharmProjects/Image Recognition/Project - Jurassic Park/dataset"))

# initialize the list of known encodings and known names
knownEncodings = []
knownNames = []
# Out:
# [INFO] quantifying faces...

# %%
# loop over the image paths
for (i, imagePath) in enumerate(imagePaths):
    
    # extract the person name from the image path
    print("[INFO] processing image {}/{}".format(i + 1,len(imagePaths)))
    name = imagePath.split(os.path.sep)[-2]
#     print(name)

    # load the input image and convert it from BGR (OpenCV ordering) to dlib ordering (RGB)
    
    image = cv2.imread(imagePath)
    rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    
    # detect the (x, y)-coordinates of the bounding boxes corresponding to each face in the input image
    boxes = face_recognition.face_locations(rgb,model=args["detection_method"])

    # compute the facial embedding for the face
    encodings = face_recognition.face_encodings(rgb, boxes)
    
    # loop over the encodings
    for encoding in encodings:
        # add each encoding + name to our set of known names and encodings
        knownEncodings.append(encoding)
        knownNames.append(name)
# Out:
# [INFO] processing image 1/222
# [INFO] processing image 2/222
# [INFO] processing image 3/222
# [INFO] processing image 4/222
# [INFO] processing image 5/222
# [INFO] processing image 6/222
# [INFO] processing image 7/222
# [INFO] processing image 8/222
# [INFO] processing image 9/222
# [INFO] processing image 10/222
# [INFO] processing image 11/222
# [INFO] processing image 12/222
# [INFO] processing image 13/222
# [INFO] processing image 14/222
# [INFO] processing image 15/222
# [INFO] processing image 16/222
# [INFO] processing image 17/222
# [INFO] processing image 18/222
# [INFO] processing image 19/222
# [INFO] processing image 20/222
# [INFO] processing image 21/222
# [INFO] processing image 22/222
# [INFO] processing image 23/222
# [INFO] processing image 24/222
# [INFO] processing image 25/222
# [INFO] processing image 26/222
# [INFO] processing image 27/222
# [INFO] processing image 28/222
# [INFO] processing image 29/222
# [INFO] processing image 30/222
# ...

# %%
# dump the facial encodings + names to disk
print("[INFO] serializing encodings...")
data = {"encodings": knownEncodings, "names": knownNames}
f = open(args["encodings"], "wb")
f.write(pickle.dumps(data))
f.close()
# Out:
# [INFO] serializing encodings...

# %%
data['names']
# Out:
# ['ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'ian_malcolm',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
#  'john_hammond',
# ...
